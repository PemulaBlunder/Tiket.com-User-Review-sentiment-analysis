# %%
from bs4 import BeautifulSoup
import re

# %%
# !python scrap.py

# %%
with open("/content/playstore_reviews2.html", encoding="utf-8") as f:
    html = f.read()

soup = BeautifulSoup(html, "html.parser")

# %%
print(soup.prettify()[:5000])
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <meta content="" http-equiv="origin-trial"/>
#   <script async="" nonce="" src="https://www.googletagmanager.com/gtag/js?id=G-6VGGZHMLM2&amp;cx=c&amp;gtm=4e6691" type="text/javascript">
#   </script>
#   <script async="" charset="utf-8" crossorigin="anonymous" integrity="sha384-m1PC1ygjfLmGwsDY9jhFKKTk4uAMPEO34ag12kE5Ljsj7EXMzvB24pLZaON7S8Ds" nonce="" src="https://www.gstatic.com/recaptcha/releases/MerVUtRoajKEbP7pLiGXkL28/recaptcha__en.js" type="text/javascript">
#   </script>
#   <script async="" nonce="" src="https://www.googletagmanager.com/gtm.js?id=GTM-K59689F">
#   </script>
# ...

# %%
reviews = soup.find_all("div", class_="RHo1pe")

print(len(reviews))
# Out:
# 5380

# %%
for review in reviews[:3]:

    ratings = review.select('[role="img"][aria-label]')

    print("==== REVIEW ====")

    for r in ratings:
        print(r.get("aria-label"))
# Out:
# ==== REVIEW ====
# Rated 1 stars out of five stars
# ==== REVIEW ====
# Rated 2 stars out of five stars
# ==== REVIEW ====
# Rated 1 stars out of five stars

# %%
reviews = soup.find_all("div", class_="RHo1pe")

data=[]

for review in reviews:

    user = review.select_one(".X5PpBb")
    user = user.get_text(strip=True) if user else None

    rating = review.select_one('[role="img"][aria-label]')
    rating = rating["aria-label"] if rating else None

    comment = review.select_one(".h3YV2d")
    comment = comment.get_text(" ", strip=True) if comment else None

    print("=" * 80)
    print("User   :", user)
    print("Rating :", rating)
    print("Review :", comment)

    data.append({
        "user": user,
        "rating": rating,
        "review": comment
    })

with open("reviews.json", "w", encoding="utf-8") as f:
    json.dump(data, f, ensure_ascii=False, indent=4)

print(f"Berhasil menyimpan {len(data)} review")
# Out:
# Streaming output truncated to the last 5000 lines.
# User   : Dimas teguh Prasetyo
# Rating : Rated 5 stars out of five stars
# Review : mantap
# ...
# User   : RIZMA SIMBOLON
# Rating : Rated 5 stars out of five stars
# Review : harga kompetitif
# ...
# User   : Andy Sutikno
# Rating : Rated 5 stars out of five stars
# Review : ok bgt
# ...
# User   : Jonathan Hardianto
# Rating : Rated 1 stars out of five stars
# Review : sering error pas pemilihan pembayaran, terus pas kembali dibilang kamar penuh. ITnya ngapain aja bos?
# ...
# User   : Kenny Hogan
# Rating : Rated 1 stars out of five stars
# Review : ga jelas, pesen disini, connect aplikasi lain, cek in sulit, slow respon, tiket. com ga bs apa2
# ...
# User   : Muhammad Rifatullah
# Rating : Rated 1 stars out of five stars
# Review : halaman ferry ga bisa dibuka, loading terus
# ...
# User   : Dio
# Rating : Rated 1 stars out of five stars
# Review : lemot parah
# ...
# User   : WEELY DJALOE
# Rating : Rated 5 stars out of five stars
# Review : kerenn
# ...
